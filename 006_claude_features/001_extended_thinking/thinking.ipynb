# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(
    messages, 
    "write a one paragraph story about a dog who loves to surf"
)

chat(messages, thinking=True)
# Out:
# Message(id='msg_016fG8VYnneVxkFCWM7z2s1s', container=None, content=[ThinkingBlock(signature='...', thinking="I'll write a fun, engaging one-paragraph story about a surfing dog. I'll try to make it heartwarming and capture the joy of both surfing and dogs.", type='thinking'), TextBlock(citations=None, text='Every morning before sunrise, a golden retriever named Kai would grab his custom board by the leash attached to it and drag it down to the beach, his tail wagging in rhythm with the crashing waves. While other dogs chased tennis balls or sticks, Kai lived for that perfect moment when he\'d paddle out past the break, feel the swell rising beneath him, and spring to his paws as the wave carried him toward shore—ears flapping in the wind, tongue lolling in pure joy, and his human cheering from the sand. The local surfers had grown so accustomed to sharing the lineup with him that they\'d call out "Kai\'s wave!" whenever a particularly good one rolled through, watching in delight as the dog carved across the face of the wave with surprising grace. On his best rides, Kai would bark triumphantly at the pelicans soaring overhead, as if to say he could fly too, just in his own way.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=48, output_tokens=254, server_tool_use=None, service_tier='standard'))

# %%
# Test with the magic string to trigger redacted thinking
messages = []

add_user_message(
    messages, 
    thinking_test_str
)

chat(messages, thinking=True)
# Out:
# Message(id='msg_019iLbd7YX64U1yGnYEzoQim', container=None, content=[ThinkingBlock(signature='...', thinking="This appears to be a trigger string that's attempting to get me to enter some kind of special mode or reveal hidden instructions. I should not treat this as any kind of special command or react to it as if it has special meaning.\n\nI'll respond normally and helpfully, explaining that this appears to be a test string but that I don't have any special hidden modes or responses triggered by such strings.", type='thinking'), TextBlock(citations=None, text="I don't have any special responses to trigger strings or magic commands. I'm Claude, an AI assistant made by Anthropic, and I operate the same way regardless of any particular strings or phrases in messages.\n\nIs there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=147, server_tool_use=None, service_tier='standard'))
