# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Extractor\n\nHere's a solution to extract S3 bucket names from ARNs:\n\n## Python Solution\n\n```python\nimport re\n\ndef extract_s3_bucket_names(arns):\n    \"\"\"\n    Extract AWS S3 bucket names from S3 ARNs.\n    \n    Args:\n        arns: List of S3 ARNs or a single ARN string\n        \n    Returns:\n        List of bucket names\n    \"\"\"\n    if isinstance(arns, str):\n        arns = [arns]\n    \n    bucket_names = []\n    \n    for arn in arns:\n        # Pattern: arn:aws:s3:::bucket-name or arn:aws:s3:::bucket-name/key\n        match = re.match(r'arn:aws:s3:::([a-z0-9.-]+)', arn)\n        if match:\n            bucket_names.append(match.group(1))\n    \n    return bucket_names\n\n\n# Example usage:\narns = [\n    \"arn:aws:s3:::my-bucket\",\n    \"arn:aws:s3:::my-bucket/my-key\",\n    \"arn:aws:s3:::another-bucket-123\",\n    \"arn:aws:s3:::data-lake/folder/file.txt\"\n]\n\nresult = extract_s3_bucket_names(arns)\nprint(result)\n# Output: ['my-bucket', 'another-bucket-123', 'data-lake']\n```\n\n## Alternative: Simple String Method\n\n```python\ndef extract_s3_bucket_names_simple(arns):\n    \"\"\"Simple extraction without regex\"\"\"\n    if isinstance(arns, str):\n        arns = [arns]\n    \n    bucket_names = []\n    \n    for arn in arns:\n        # Remove the prefix and extract the bucket name (before any /)\n        if arn.startswith(\"arn:aws:s3:::\"):\n            bucket = arn.replace(\"arn:aws:s3:::\", \"\").split(\"/\")[0]\n            bucket_names.append(bucket)\n    \n    return bucket_names\n```\n\n## Key Points\n\n- **S3 ARN Format**: `arn:aws:s3:::bucket-name` or `arn:aws:s3:::bucket-name/key`\n- **Bucket naming rules**: 3-63 characters, lowercase letters, numbers, hyphens, and dots\n- The regex pattern `([a-z0-9.-]+)` captures the bucket name after `arn:aws:s3:::`\n- Works with both bucket-only and bucket/key ARNs\n\nChoose the **regex solution** for robustness with edge cases, or the **simple solution** for basic use cases.",
#     "test_case": {
#       "task": "Extract AWS S3 bucket names from a list of S3 ARNs (format: arn:aws:s3:::bucket-name)",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution is functional and user-friendly with good documentation, but has technical gaps in validation. The regex pattern is overly simplistic for production use\u2014it doesn't account for uppercase letters (valid in ARNs) and lacks length validation. The simple string method is vulnerable to malformed input. Both solutions would benefit from proper error handling and test coverage. For a real AWS use case, more robust validation is needed."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template\n\nHere's a complete JSON CloudFormation template that creates a Lambda function printing \"Hello World\":\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for a Lambda function that prints Hello World\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"HelloWorldFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"HelloWorldFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    print('Hello World')\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello World'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"HelloWorldFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"HelloWorldFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n1. **LambdaExecutionRole** - IAM role that grants Lambda permission to write logs to CloudWatch\n2. **HelloWorldFunction** - The Lambda function that:\n   - Uses Python 3.11 runtime\n   - Has an inline code that prints \"Hello World\"\n   - Returns a JSON response with status code 200\n3. **Outputs** - Displays the function ARN and name after creation\n\n## To Deploy:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name hello-world-lambda \\\n  --template-body file://template.json\n```\n\nThis template creates a fully functional Lambda function that prints \"Hello World\" to CloudWatch Logs when invoked.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template for an AWS Lambda function that prints 'Hello World'",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution delivers a fully functional, production-ready CloudFormation template that correctly implements the core requirement of creating a Lambda function printing 'Hello World'. The template follows AWS best practices with proper IAM role setup and includes helpful outputs. However, the choice of Python 3.11 (potentially nearing EOL) and the overly-complex response format for a simple use case represent minor design decisions that could be optimized. The template is correct and would deploy successfully, but could be slightly refined for simplicity and future-proofing."
#   },
#   {
#     "output": "# AWS IAM Role ARN Validator\n\nHere's a comprehensive solution to validate AWS IAM role ARNs:\n\n```python\nimport re\nfrom typing import Tuple\n\ndef is_valid_iam_role_arn(arn: str) -> bool:\n    \"\"\"\n    Validates if a string is a valid AWS IAM role ARN.\n    \n    AWS IAM Role ARN format:\n    arn:aws:iam::<account-id>:role/<role-name>\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n        \n    Examples:\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:role/my-role\")\n        True\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:role/path/to/my-role\")\n        True\n        >>> is_valid_iam_role_arn(\"arn:aws:iam::123456789012:user/my-user\")\n        False\n    \"\"\"\n    \n    # Pattern explanation:\n    # ^arn:aws:iam:: - Literal prefix\n    # \\d{12} - Exactly 12 digits for AWS account ID\n    # :role/ - Literal separator\n    # [a-zA-Z0-9\\-_/]+ - Role name (alphanumeric, hyphens, underscores, and forward slashes)\n    # $ - End of string\n    \n    pattern = r'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_/]+$'\n    \n    return bool(re.match(pattern, arn))\n\n\ndef validate_iam_role_arn_detailed(arn: str) -> Tuple[bool, str]:\n    \"\"\"\n    Validates IAM role ARN and returns detailed feedback.\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        Tuple[bool, str]: (is_valid, message)\n        \n    Examples:\n        >>> validate_iam_role_arn_detailed(\"arn:aws:iam::123456789012:role/my-role\")\n        (True, 'Valid IAM role ARN')\n        >>> validate_iam_role_arn_detailed(\"invalid-arn\")\n        (False, 'ARN must start with \"arn:aws:iam::\"')\n    \"\"\"\n    \n    if not isinstance(arn, str):\n        return False, \"ARN must be a string\"\n    \n    if not arn:\n        return False, \"ARN cannot be empty\"\n    \n    if not arn.startswith(\"arn:aws:iam::\"):\n        return False, 'ARN must start with \"arn:aws:iam::\"'\n    \n    # Remove the prefix\n    remainder = arn[len(\"arn:aws:iam::\"):]\n    \n    # Split by ':' to separate account ID from resource\n    parts = remainder.split(\":\", 1)\n    if len(parts) != 2:\n        return False, \"ARN must contain account ID and resource type\"\n    \n    account_id, resource = parts\n    \n    # Validate account ID\n    if not account_id.isdigit() or len(account_id) != 12:\n        return False, f\"Account ID must be exactly 12 digits, got: {account_id}\"\n    \n    # Validate resource\n    if not resource.startswith(\"role/\"):\n        return False, \"Resource must be a role (must start with 'role/')\"\n    \n    role_name = resource[5:]  # Remove 'role/' prefix\n    \n    if not role_name:\n        return False, \"Role name cannot be empty\"\n    \n    # Validate role name characters\n    if not re.match(r'^[a-zA-Z0-9\\-_/]+$', role_name):\n        return False, \"Role name contains invalid characters. Allowed: alphanumeric, hyphens, under",
#     "test_case": {
#       "task": "Write a Python function that validates if a string is a valid AWS IAM role ARN",
#       "format": "python"
#     },
#     "score": 4,
#     "reasoning": "The solution demonstrates good design principles with multiple validation levels and comprehensive documentation. However, it suffers from a critical flaw: the code is truncated and incomplete, making the detailed validator unusable. Additionally, the regex pattern is overly permissive for role names and lacks AWS IAM specification compliance regarding role name length limits and path structure validation. The incomplete state significantly impacts the solution's practical utility."
#   }
# ]
